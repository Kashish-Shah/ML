# %%
import numpy as np

import pandas as pd
 
import matplotlib.pyplot as plt
 
import statsmodels.api as sm
 
import seaborn
 
seaborn.set()

# %%
df = pd.read_csv("C:/Users/aayushi/Desktop/Kashish sem-6/ML/Practical-2/titanic.csv" )
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
x1= df[['Pclass']]

y=df[['Survived']]

# %%
x = sm.add_constant(x1)
 
results = sm.OLS(y,x).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.112
# Method:                 Least Squares   F-statistic:                     113.0
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           6.30e-25
# Time:                        10:25:38   Log-Likelihood:                -566.61
# No. Observations:                 887   AIC:                             1137.
# Df Residuals:                     885   BIC:                             1147.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8372      0.045     18.527      0.000       0.749       0.926
# Pclass        -0.1959      0.018    -10.631      0.000      -0.232      -0.160
# ==============================================================================
# Omnibus:                     1566.947   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.643
# Skew:                           0.422   Prob(JB):                     9.30e-20
# Kurtosis:                       1.712   Cond. No.                         8.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
dummy=pd.get_dummies(df['Sex'])
dummy.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
df1=pd.concat((df,dummy),axis=1)

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500
#
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
df1=df1.drop(['Sex','male'],axis=1)
df1.head()
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0         0       3                             Mr. Owen Harris Braund  22.0
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  38.0
# 2         1       3                              Miss. Laina Heikkinen  26.0
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle  35.0
# 4         0       3                            Mr. William Henry Allen  35.0
#
#    Siblings/Spouses Aboard  Parents/Children Aboard     Fare  female
# 0                        1                        0   7.2500       0
# 1                        1                        0  71.2833       1
# 2                        0                        0   7.9250       1
# 3                        1                        0  53.1000       1
# 4                        0                        0   8.0500       0

# %%
x2= df1[['female']]

y=df1[['Survived']]

# %%
x = sm.add_constant(x2)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     368.4
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           6.43e-69
# Time:                        10:27:59   Log-Likelihood:                -465.56
# No. Observations:                 887   AIC:                             935.1
# Df Residuals:                     885   BIC:                             944.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1902      0.017     11.121      0.000       0.157       0.224
# female         0.5518      0.029     19.194      0.000       0.495       0.608
# ==============================================================================
# Omnibus:                       24.739   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.404
# Skew:                           0.422   Prob(JB):                     1.85e-06
# Kurtosis:                       2.944   Cond. No.                         2.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x3= df1[['Age']]

y=df1[['Survived']]

# %%
x = sm.add_constant(x3)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.162
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):             0.0757
# Time:                        10:29:05   Log-Likelihood:                -618.34
# No. Observations:                 887   AIC:                             1241.
# Df Residuals:                     885   BIC:                             1250.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4462      0.038     11.801      0.000       0.372       0.520
# Age           -0.0021      0.001     -1.778      0.076      -0.004       0.000
# ==============================================================================
# Omnibus:                     4076.811   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.680
# Skew:                           0.468   Prob(JB):                     8.55e-33
# Kurtosis:                       1.234   Cond. No.                         75.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x4= df1[['Siblings/Spouses Aboard']]

y=df1[['Survived']]

# %%
x = sm.add_constant(x4)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.219
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):              0.270
# Time:                        10:30:02   Log-Likelihood:                -619.31
# No. Observations:                 887   AIC:                             1243.
# Df Residuals:                     885   BIC:                             1252.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.3942      0.018     21.769      0.000       0.359       0.430
# Siblings/Spouses Aboard    -0.0163      0.015     -1.104      0.270      -0.045       0.013
# ==============================================================================
# Omnibus:                     4035.766   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              148.922
# Skew:                           0.467   Prob(JB):                     4.59e-33
# Kurtosis:                       1.224   Cond. No.                         1.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x5= df1[['Parents/Children Aboard']]

y=df1[['Survived']]

# %%
x = sm.add_constant(x5)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     5.714
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):             0.0170
# Time:                        10:30:53   Log-Likelihood:                -617.06
# No. Observations:                 887   AIC:                             1238.
# Df Residuals:                     885   BIC:                             1248.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.3671      0.018     20.330      0.000       0.332       0.402
# Parents/Children Aboard     0.0483      0.020      2.390      0.017       0.009       0.088
# ==============================================================================
# Omnibus:                     4123.056   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              145.511
# Skew:                           0.463   Prob(JB):                     2.53e-32
# Kurtosis:                       1.245   Cond. No.                         1.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x6= df1[['Fare']]

y=df1[['Survived']]

# %%
x = sm.add_constant(x6)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     62.16
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           9.29e-15
# Time:                        10:31:42   Log-Likelihood:                -589.81
# No. Observations:                 887   AIC:                             1184.
# Df Residuals:                     885   BIC:                             1193.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3046      0.019     16.154      0.000       0.268       0.342
# Fare           0.0025      0.000      7.884      0.000       0.002       0.003
# ==============================================================================
# Omnibus:                     5454.966   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              125.259
# Skew:                           0.483   Prob(JB):                     6.32e-28
# Kurtosis:                       1.433   Cond. No.                         70.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x7= df1[['Pclass','female','Fare']]

y=df1[['Survived']]

# %%
x = sm.add_constant(x7)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.366
# Model:                            OLS   Adj. R-squared:                  0.364
# Method:                 Least Squares   F-statistic:                     170.2
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           4.50e-87
# Time:                        10:33:11   Log-Likelihood:                -417.52
# No. Observations:                 887   AIC:                             843.0
# Df Residuals:                     883   BIC:                             862.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5437      0.052     10.462      0.000       0.442       0.646
# Pclass        -0.1506      0.019     -8.066      0.000      -0.187      -0.114
# female         0.5135      0.028     18.511      0.000       0.459       0.568
# Fare           0.0002      0.000      0.705      0.481      -0.000       0.001
# ==============================================================================
# Omnibus:                       40.285   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.937
# Skew:                           0.551   Prob(JB):                     1.75e-10
# Kurtosis:                       3.056   Cond. No.                         251.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x8= df1[['Age','female','Fare']]

y=df1[['Survived']]

# %%
x = sm.add_constant(x8)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.318
# Method:                 Least Squares   F-statistic:                     139.0
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           9.57e-74
# Time:                        10:34:41   Log-Likelihood:                -448.41
# No. Observations:                 887   AIC:                             904.8
# Df Residuals:                     883   BIC:                             924.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1815      0.034      5.359      0.000       0.115       0.248
# Age           -0.0011      0.001     -1.129      0.259      -0.003       0.001
# female         0.5180      0.029     17.924      0.000       0.461       0.575
# Fare           0.0016      0.000      5.890      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                       27.924   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.099
# Skew:                           0.450   Prob(JB):                     2.91e-07
# Kurtosis:                       2.946   Cond. No.                         171.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x9= df1[['Age','Pclass','female','Siblings/Spouses Aboard','Parents/Children Aboard','Fare']]

y=df1[['Survived']]

# %%
x = sm.add_constant(x9)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Survived   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.393
# Method:                 Least Squares   F-statistic:                     96.76
# Date:                Thu, 28 Jan 2021   Prob (F-statistic):           2.36e-93
# Time:                        10:35:58   Log-Likelihood:                -395.22
# No. Observations:                 887   AIC:                             804.4
# Df Residuals:                     880   BIC:                             837.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.8243      0.072     11.450      0.000       0.683       0.966
# Age                        -0.0062      0.001     -5.983      0.000      -0.008      -0.004
# Pclass                     -0.1800      0.020     -8.957      0.000      -0.219      -0.141
# female                      0.5077      0.028     18.159      0.000       0.453       0.563
# Siblings/Spouses Aboard    -0.0503      0.013     -3.811      0.000      -0.076      -0.024
# Parents/Children Aboard    -0.0193      0.018     -1.067      0.286      -0.055       0.016
# Fare                        0.0004      0.000      1.249      0.212      -0.000       0.001
# ==============================================================================
# Omnibus:                       36.406   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.033
# Skew:                           0.519   Prob(JB):                     2.03e-09
# Kurtosis:                       3.085   Cond. No.                         365.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
