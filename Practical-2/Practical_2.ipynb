# %%
import numpy as np

import pandas as pd
 
import matplotlib.pyplot as plt
 
import statsmodels.api as sm
 
import seaborn
 
seaborn.set()

# %%
df = pd.read_csv("C:/Users/aayushi/Desktop/Kashish sem-6/ML/Practical-2/titanic.csv" )
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
x1= df[['Survived']]

y=df[['Fare']]

# %%
x = sm.add_constant(x1)
 
results = sm.OLS(y,x).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     62.16
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):           9.29e-15
# Time:                        16:54:49   Log-Likelihood:                -4694.1
# No. Observations:                 887   AIC:                             9392.
# Df Residuals:                     885   BIC:                             9402.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.2086      2.062     10.768      0.000      18.161      26.256
# ...

# %%
dummy=pd.get_dummies(df['Sex'])
dummy.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
df1=pd.concat((df,dummy),axis=1)

# %%
df1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500
#
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# ...

# %%
df1=df1.drop(['Sex','male'],axis=1)
df1.head()
# Out:
#    Survived  Pclass                                               Name   Age  \
# 0         0       3                             Mr. Owen Harris Braund  22.0
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...  38.0
# 2         1       3                              Miss. Laina Heikkinen  26.0
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle  35.0
# 4         0       3                            Mr. William Henry Allen  35.0
#
#    Siblings/Spouses Aboard  Parents/Children Aboard     Fare  female
# 0                        1                        0   7.2500       0
# 1                        1                        0  71.2833       1
# 2                        0                        0   7.9250       1
# 3                        1                        0  53.1000       1
# 4                        0                        0   8.0500       0

# %%
x2= df1[['female']]

y=df1[['Fare']]

# %%
x = sm.add_constant(x2)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     30.02
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):           5.57e-08
# Time:                        16:57:43   Log-Likelihood:                -4709.4
# No. Observations:                 887   AIC:                             9423.
# Df Residuals:                     885   BIC:                             9432.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         25.6339      2.046     12.526      0.000      21.618      29.650
# ...

# %%
x3= df1[['Pclass']]

y=df1[['Fare']]

# %%
x = sm.add_constant(x3)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.301
# Method:                 Least Squares   F-statistic:                     381.7
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):           6.07e-71
# Time:                        16:59:52   Log-Likelihood:                -4565.2
# No. Observations:                 887   AIC:                             9134.
# Df Residuals:                     885   BIC:                             9144.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        107.6064      4.100     26.245      0.000      99.559     115.654
# ...

# %%
x4= df1[['Age']]

y=df1[['Fare']]

# %%
x = sm.add_constant(x4)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     11.31
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):           0.000804
# Time:                        17:16:59   Log-Likelihood:                -4718.6
# No. Observations:                 887   AIC:                             9441.
# Df Residuals:                     885   BIC:                             9451.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.6354      3.848      5.363      0.000      13.084      28.187
# ...

# %%
x5= df1[['Siblings/Spouses Aboard']]

y=df1[['Fare']]

# %%
x = sm.add_constant(x5)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     22.91
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):           1.99e-06
# Time:                        17:19:45   Log-Likelihood:                -4712.9
# No. Observations:                 887   AIC:                             9430.
# Df Residuals:                     885   BIC:                             9439.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
x6= df1[['Parents/Children Aboard']]

y=df1[['Fare']]

# %%
x = sm.add_constant(x6)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     43.09
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):           8.90e-11
# Time:                        17:20:57   Log-Likelihood:                -4703.1
# No. Observations:                 887   AIC:                             9410.
# Df Residuals:                     885   BIC:                             9420.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
x7= df1[['Age','female','Survived']]

y=df1[['Fare']]

# %%
x = sm.add_constant(x7)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     27.52
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):           5.09e-17
# Time:                        17:31:22   Log-Likelihood:                -4684.5
# No. Observations:                 887   AIC:                             9377.
# Df Residuals:                     883   BIC:                             9396.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0537      4.075      1.731      0.084      -0.944      15.052
# ...

# %%
x8= df1[['Age','Pclass','Survived']]

y=df1[['Fare']]

# %%
x = sm.add_constant(x8)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.316
# Model:                            OLS   Adj. R-squared:                  0.314
# Method:                 Least Squares   F-statistic:                     136.3
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):           1.46e-72
# Time:                        17:32:51   Log-Likelihood:                -4555.4
# No. Observations:                 887   AIC:                             9119.
# Df Residuals:                     883   BIC:                             9138.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        119.7613      7.257     16.502      0.000     105.518     134.005
# ...

# %%
x9= df1[['Age','Pclass','Survived','female','Siblings/Spouses Aboard','Parents/Children Aboard']]

y=df1[['Fare']]

# %%
x = sm.add_constant(x9)
 
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.373
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     87.26
# Date:                Wed, 27 Jan 2021   Prob (F-statistic):           8.39e-86
# Time:                        17:49:36   Log-Likelihood:                -4517.1
# No. Observations:                 887   AIC:                             9048.
# Df Residuals:                     880   BIC:                             9082.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...
